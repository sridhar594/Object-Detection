# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python mediapipe sklearn matplotlib

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import string
import tensorflow

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS ) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image,results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# %%
face
# Out:
# array([ 0.49058396,  0.61258793, -0.02756642, ...,  0.53584445,
#         0.49017447,  0.02553307])

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.48495808,  0.56281483, -0.78850186, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.48495808,  0.56281483, -0.78850186, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 
print(os.getcwd())
list1=['hello', 'thanks',"good" ,"Please","stop"]


# Actions that we try to detect
actions = np.array(list1)

print(actions)    

# Thirty videos worth of data
no_sequences = 60

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30
# Out:
# C:\Users\LENOVO\Documents\GitHub\ActionDetectionforSignLanguage
# ['hello' 'thanks' 'good' 'Please' 'stop']

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %%
action="stop"
for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    action="stop"
    # Loop through sequences aka videos
    for sequence in range(no_sequences):
        # Loop through video length aka sequence length
        for frame_num in range(sequence_length):

            # Read feed
            ret, frame = cap.read()

            # Make detections
            image, results = mediapipe_detection(frame, holistic)
#           print(results)

            # Draw landmarks
            draw_styled_landmarks(image, results)
                
            # NEW Apply wait logic
            if frame_num == 0: 
                cv2.putText(image, 'STARTING COLLECTION'+ action, (120,200), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                # Show to screen
                cv2.imshow('OpenCV Feed', image)
                cv2.waitKey(2000)
            else: 
                cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                # Show to screen
                cv2.imshow('OpenCV Feed', image)
                
            # NEW Export keypoints
            keypoints = extract_keypoints(results)
            npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
            np.save(npy_path, keypoints)

            # Break gracefully
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
                    
cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'good': 2, 'Please': 3, 'stop': 4}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (300, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (300,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (300, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

# %%
y_test.shape
# Out:
# (45, 5)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=False  , activation="relu", input_shape=(30,1662)))


model.add(Dense(64, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=80, callbacks=[tb_callback])
# Out:
# Epoch 1/80
# 8/8 [==============================] - 4s 48ms/step - loss: 2.3345 - categorical_accuracy: 0.2863
# Epoch 2/80
# 8/8 [==============================] - 0s 40ms/step - loss: 1.8518 - categorical_accuracy: 0.2157
# Epoch 3/80
# 8/8 [==============================] - 0s 42ms/step - loss: 2.7938 - categorical_accuracy: 0.2863
# Epoch 4/80
# 8/8 [==============================] - 0s 48ms/step - loss: 2.0669 - categorical_accuracy: 0.2353
# Epoch 5/80
# 8/8 [==============================] - 0s 47ms/step - loss: 1.8910 - categorical_accuracy: 0.2471
# Epoch 6/80
# 8/8 [==============================] - 0s 37ms/step - loss: 1.6148 - categorical_accuracy: 0.2118
# Epoch 7/80
# 8/8 [==============================] - 0s 45ms/step - loss: 1.3536 - categorical_accuracy: 0.4314
# Epoch 8/80
# 8/8 [==============================] - 0s 44ms/step - loss: 1.2507 - categorical_accuracy: 0.4000
# Epoch 9/80
# 8/8 [==============================] - 0s 46ms/step - loss: 1.1770 - categorical_accuracy: 0.5451
# Epoch 10/80
# 8/8 [==============================] - 0s 45ms/step - loss: 1.0727 - categorical_accuracy: 0.5647
# Epoch 11/80
# 8/8 [==============================] - 0s 42ms/step - loss: 0.9526 - categorical_accuracy: 0.5843
# Epoch 12/80
# 8/8 [==============================] - 0s 40ms/step - loss: 0.8559 - categorical_accuracy: 0.6510
# Epoch 13/80
# 8/8 [==============================] - 0s 60ms/step - loss: 0.7873 - categorical_accuracy: 0.6392
# Epoch 14/80
# 8/8 [==============================] - 0s 53ms/step - loss: 0.7603 - categorical_accuracy: 0.5961
# Epoch 15/80
# 8/8 [==============================] - 0s 43ms/step - loss: 0.6961 - categorical_accuracy: 0.6627
# Epoch 16/80
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6210 - categorical_accuracy: 0.7020
# Epoch 17/80
# 8/8 [==============================] - 0s 42ms/step - loss: 0.5811 - categorical_accuracy: 0.6980
# Epoch 18/80
# 8/8 [==============================] - 0s 42ms/step - loss: 0.5940 - categorical_accuracy: 0.6745
# Epoch 19/80
# 8/8 [==============================] - 0s 49ms/step - loss: 0.6164 - categorical_accuracy: 0.7216
# Epoch 20/80
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5944 - categorical_accuracy: 0.7098
# Epoch 21/80
# 8/8 [==============================] - 0s 52ms/step - loss: 0.5893 - categorical_accuracy: 0.6902
# Epoch 22/80
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5056 - categorical_accuracy: 0.7922
# Epoch 23/80
# 8/8 [==============================] - 0s 44ms/step - loss: 0.4688 - categorical_accuracy: 0.8078
# Epoch 24/80
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3825 - categorical_accuracy: 0.8824
# Epoch 25/80
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6333 - categorical_accuracy: 0.7176
# Epoch 26/80
# 8/8 [==============================] - 0s 40ms/step - loss: 0.5854 - categorical_accuracy: 0.7216
# Epoch 27/80
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4687 - categorical_accuracy: 0.7922
# Epoch 28/80
# 8/8 [==============================] - 0s 45ms/step - loss: 0.4683 - categorical_accuracy: 0.7922
# Epoch 29/80
# 8/8 [==============================] - 0s 55ms/step - loss: 0.3735 - categorical_accuracy: 0.8588
# Epoch 30/80
# 8/8 [==============================] - 0s 44ms/step - loss: 0.3738 - categorical_accuracy: 0.8275
# Epoch 31/80
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2768 - categorical_accuracy: 0.9255
# Epoch 32/80
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3024 - categorical_accuracy: 0.8902
# Epoch 33/80
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2109 - categorical_accuracy: 0.9490
# Epoch 34/80
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2137 - categorical_accuracy: 0.9176
# Epoch 35/80
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6036 - categorical_accuracy: 0.8196
# Epoch 36/80
# 8/8 [==============================] - 0s 42ms/step - loss: 0.8239 - categorical_accuracy: 0.7451
# Epoch 37/80
# 8/8 [==============================] - 0s 44ms/step - loss: 0.4659 - categorical_accuracy: 0.7765
# Epoch 38/80
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3640 - categorical_accuracy: 0.8353
# Epoch 39/80
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2697 - categorical_accuracy: 0.9137
# Epoch 40/80
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3065 - categorical_accuracy: 0.8627
# Epoch 41/80
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3337 - categorical_accuracy: 0.8471
# Epoch 42/80
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2285 - categorical_accuracy: 0.9529
# Epoch 43/80
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1823 - categorical_accuracy: 0.9647
# Epoch 44/80
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1635 - categorical_accuracy: 0.9647
# Epoch 45/80
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2563 - categorical_accuracy: 0.9294
# Epoch 46/80
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3077 - categorical_accuracy: 0.8902
# Epoch 47/80
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2266 - categorical_accuracy: 0.9020
# Epoch 48/80
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1861 - categorical_accuracy: 0.9412
# Epoch 49/80
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1604 - categorical_accuracy: 0.9490
# Epoch 50/80
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1336 - categorical_accuracy: 0.9725
# Epoch 51/80
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1395 - categorical_accuracy: 0.9647
# Epoch 52/80
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1200 - categorical_accuracy: 0.9725
# Epoch 53/80
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1327 - categorical_accuracy: 0.9608
# Epoch 54/80
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1454 - categorical_accuracy: 0.9373
# Epoch 55/80
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1066 - categorical_accuracy: 0.9725
# Epoch 56/80
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1014 - categorical_accuracy: 0.9765
# Epoch 57/80
# 8/8 [==============================] - 0s 41ms/step - loss: 0.0690 - categorical_accuracy: 0.9882
# Epoch 58/80
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0678 - categorical_accuracy: 0.9882
# Epoch 59/80
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1120 - categorical_accuracy: 0.9686
# Epoch 60/80
# 8/8 [==============================] - 0s 37ms/step - loss: 0.0893 - categorical_accuracy: 0.9647
# Epoch 61/80
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1763 - categorical_accuracy: 0.9255
# Epoch 62/80
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1694 - categorical_accuracy: 0.9216
# Epoch 63/80
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1437 - categorical_accuracy: 0.9529
# Epoch 64/80
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1064 - categorical_accuracy: 0.9647
# Epoch 65/80
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0924 - categorical_accuracy: 0.9608
# Epoch 66/80
# 8/8 [==============================] - 0s 41ms/step - loss: 0.0496 - categorical_accuracy: 0.9922
# Epoch 67/80
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0718 - categorical_accuracy: 0.9725
# Epoch 68/80
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1150 - categorical_accuracy: 0.9608
# Epoch 69/80
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1401 - categorical_accuracy: 0.9373
# Epoch 70/80
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1076 - categorical_accuracy: 0.9490
# Epoch 71/80
# 8/8 [==============================] - 0s 40ms/step - loss: 0.4020 - categorical_accuracy: 0.8157
# Epoch 72/80
# 8/8 [==============================] - 0s 42ms/step - loss: 0.5042 - categorical_accuracy: 0.7804
# Epoch 73/80
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2269 - categorical_accuracy: 0.9020
# Epoch 74/80
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1739 - categorical_accuracy: 0.9451
# Epoch 75/80
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1157 - categorical_accuracy: 0.9647
# Epoch 76/80
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1136 - categorical_accuracy: 0.9686
# Epoch 77/80
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1573 - categorical_accuracy: 0.9373
# Epoch 78/80
# 8/8 [==============================] - 0s 43ms/step - loss: 0.0857 - categorical_accuracy: 0.9725
# Epoch 79/80
# 8/8 [==============================] - 0s 40ms/step - loss: 0.0724 - categorical_accuracy: 0.9765
# Epoch 80/80
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0489 - categorical_accuracy: 0.9882

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                442112
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 448,517
# Trainable params: 448,517
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[1])]
# Out:
# 'thanks'

# %%
actions[np.argmax(y_test[1])]
# Out:
# 'thanks'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[31,  0],
#         [ 2, 12]],
#
#        [[38,  0],
#         [ 0,  7]],
#
#        [[35,  2],
#         [ 0,  8]],
#
#        [[37,  1],
#         [ 1,  6]],
#
#        [[36,  0],
#         [ 0,  9]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.9333333333333333

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245),(245,117,16), (117,245,16), (16,117,245),(245,117,16)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.95

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# ...
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# good
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# Please
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# stop

# %%
    cap.release()
    cv2.destroyAllWindows()
